# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import regdata as rd

# %% [markdown]
# ### Della Gatta Gene

# %%
rd.DellaGattaGene().plot();

# %% [markdown]
# ### Motorcycle Helmet

# %%
rd.MotorcycleHelmet().plot();

# %% [markdown]
# ### Olympic

# %%
rd.Olympic().plot();

# %% [markdown]
# ### SineJump1D

# %%
rd.SineJump1D(scale_X=False, mean_normalize_y=False).plot();

# %% [markdown]
# ### Smooth1D

# %%
rd.Smooth1D(scale_X=False, mean_normalize_y=False).plot();

# %% [markdown]
# ### Step

# %%
rd.Step().plot();
